# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("house.csv")

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  4000       2.0   25  600000
# 3  2800       NaN   18  530000
# 4  3200       4.0   22  620000
# 5  4200       2.0   28  650000
# 6  2500       3.0   16  500000
# 7  3500       NaN   23  630000
# 8  4500       2.0   29  680000
# 9  2700       3.0   17  520000

# %% [markdown]
# Data Preprocessing: Fill NA values with median value of a column

# %%
df.bedrooms.median()
# Out:
# np.float64(3.0)

# %%
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  4000       2.0   25  600000
# 3  2800       3.0   18  530000
# 4  3200       4.0   22  620000
# 5  4200       2.0   28  650000
# 6  2500       3.0   16  500000
# 7  3500       3.0   23  630000
# 8  4500       2.0   29  680000
# 9  2700       3.0   17  520000

# %%
reg = linear_model.LinearRegression()
reg.fit(df.drop('price',axis='columns'),df.price)
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([   48.36845341, 42710.32921581,  9071.79587502])

# %%
reg.intercept_
# Out:
# np.float64(107794.89687552414)

# %%
import pandas as pd

# %%
user_input ={'areas':3000,'bedrooms':3, 'age':34}

# %%
user_input = pd.DataFrame(user_input,index=[0])

# %%
user_input
# Out:
#    areas  bedrooms  age
# 0   3000         3   34

# %%
reg.predict(user_input)
# Out:
# d:\a27_YEARS_OLD\machine_learning\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([743903.07976077])

# %%
48.36845341*3000 + 42710.32921581*3 + 9071.79587502*40 + 107794.89687552414
# Out:
# 743903.0797537542
